# %% [markdown]
# <a href="https://colab.research.google.com/github/Gunseerat/Gunseerat/blob/main/titanic_data_set_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Getting libraries into project

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read dataset into a variable

# %%
titanic_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/First_ML_Model/master/titanic.csv", index_col = 'PassengerId')

# %% [markdown]
# check for how your dataset actually looks

# %%
titanic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# checking for missing values

# %%
pd.isna(titanic_data["Fare"])
# Out:
# PassengerId
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Fare, Length: 891, dtype: bool

# %% [markdown]
# you can also count the unique values in a column

# %%
titanic_data.Sex.value_counts()
titanic_data.SibSp.value_counts()
titanic_data.Survived.value_counts()
titanic_data.Name.unique
# Out:
# <bound method Series.unique of PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
#                              ...
# 887                                Montvila, Rev. Juozas
# 888                         Graham, Miss. Margaret Edith
# 889             Johnston, Miss. Catherine Helen "Carrie"
# 890                                Behr, Mr. Karl Howell
# 891                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object>

# %% [markdown]
# how about finding a median score for a column

# %%
titanic_data.Fare.median()
titanic_data.Age.median()
# Out:
# 28.0

# %% [markdown]
# how about percentage of surviving male and female population
# You can surely query your dataframe for this...

# %%
survived_data = titanic_data.loc[titanic_data['Survived']==1,:]
survived_data.groupby('Embarked').count()
# Out:
#           Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin
# Embarked
# C               93      93    93   93   79     93     93      93    93     52
# Q               30      30    30   30    8     30     30      30    30      2
# S              217     217   217  217  201    217    217     217   217     80

# %%
titanic_data.nlargest(5,['Fare'])
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 259                 1       1                    Ward, Miss. Anna  female
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1              Lesurer, Mr. Gustave J    male
# 28                  0       1      Fortune, Mr. Charles Alexander    male
# 89                  1       1          Fortune, Miss. Mabel Helen  female
#
#               Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292          NaN        C
# 680          36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.3292         B101        C
# 28           19.0      3      2     19950  263.0000  C23 C25 C27        S
# 89           23.0      3      2     19950  263.0000  C23 C25 C27        S
